# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")
model.train(
    data="clean_env_data.yaml",
    epochs=60,
    imgsz=640,
    verbose=True
)
# Out:
# ...
# New https://pypi.org/project/ultralytics/8.3.253 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.252  Python-3.13.9 torch-2.9.1+cpu CPU (12th Gen Intel Core i7-12650H)
# ...

# %%
model = YOLO('runs/detect/train/weights/best.pt')

model.predict(
  source='TrainingImages/CleanEnvBarGraphs/Labelled/data/val/images',
  save=True
)
# Out:
# image 1/10 c:\Users\hkevi\Documents\Coding\BarGraphDetection\TrainingImages\CleanEnvBarGraphs\Labelled\data\val\images\12aa5989-bar_graph_0004.png: 448x640 1 Graph, 77.2ms
# image 2/10 c:\Users\hkevi\Documents\Coding\BarGraphDetection\TrainingImages\CleanEnvBarGraphs\Labelled\data\val\images\5781b6e1-bar_graph_0028.png: 448x640 1 Graph, 73.7ms
# image 3/10 c:\Users\hkevi\Documents\Coding\BarGraphDetection\TrainingImages\CleanEnvBarGraphs\Labelled\data\val\images\64abfd14-bar_graph_0062.png: 448x640 1 Graph, 64.7ms
# image 4/10 c:\Users\hkevi\Documents\Coding\BarGraphDetection\TrainingImages\CleanEnvBarGraphs\Labelled\data\val\images\88232c23-bar_graph_0048.png: 448x640 1 Graph, 65.4ms
# image 5/10 c:\Users\hkevi\Documents\Coding\BarGraphDetection\TrainingImages\CleanEnvBarGraphs\Labelled\data\val\images\d0822b5f-bar_graph_0067.png: 448x640 1 Graph, 67.2ms
# ...
